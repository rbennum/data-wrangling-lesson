# %%
import pandas as pd

# %%
obj = pd.Series([4, 7, -5, 3])

obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
print(obj.array)
print()
print(obj.index)
# Out:
# <NumpyExtensionArray>
# [np.int64(4), np.int64(7), np.int64(-5), np.int64(3)]
# Length: 4, dtype: int64
#
# RangeIndex(start=0, stop=4, step=1)

# %%
obj2 = pd.Series([4,7,-5,3], index=["d", "b",  "a", "c"])

obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2[["a","c","d"]]
# Out:
# a   -5
# c    3
# d    4
# dtype: int64

# %%
obj2[obj2 > 0]
# Out:
# d    4
# b    7
# c    3
# dtype: int64

# %%
obj2 * 2
# Out:
# d     8
# b    14
# a   -10
# c     6
# dtype: int64

# %%
print("b" in obj2)
print()
print("e" in obj2)
print()
print("B" in obj2)
# Out:
# True
#
# False
#
# False

# %%
sdata = {"Ohio":35000, "Texas": 71000, "Oregon": 16000, "Utah": 5000}

obj3 = pd.Series(sdata)

obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
states = ["California", "Ohio", "Oregon", "Texas", "Utah", "Minessota"]

obj4 = pd.Series(sdata, index=states)

obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# Utah           5000.0
# Minessota         NaN
# dtype: float64

# %%
pd.isna(obj4)
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# Utah          False
# Minessota      True
# dtype: bool

# %%
obj4.name = "population"

obj4.index.name = "state"

obj4
# Out:
# state
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# Utah           5000.0
# Minessota         NaN
# Name: population, dtype: float64

# %%
# take a look  back to obj

obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj.index = ["Bob", "Wade", "Steve", "Jeff"]

obj
# Out:
# Bob      4
# Wade     7
# Steve   -5
# Jeff     3
# dtype: int64
