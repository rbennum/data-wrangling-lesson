# %%
import pandas as pd

# %%
string_data = pd.Series(["aardvark", None, None,  "avocado"])

string_data.isna()
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# dtype: bool

# %%
float_data = pd.Series([1, 2, None], dtype='float64')

float_data
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
float_data[float_data.notna()]
# Out:
# 0    1.0
# 1    2.0
# dtype: float64

# %%
float_data2 = pd.DataFrame([[1., 6.5, 3.], [1., None, None],[None, None, None], [None, 6.5, 3.]], dtype=float)

float_data2
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
float_data2.dropna()
# Out:
#      0    1    2
# 0  1.0  6.5  3.0

# %%
float_data2.dropna(how='all')
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 3  NaN  6.5  3.0

# %%
float_data2.dropna(axis='columns')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]
